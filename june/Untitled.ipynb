# %%
import pandas as pd

df = pd.read_excel('../RESCRP11.xlsx', header=0)

# %%
print(df)
# Out:
#      Period           Transaction Plant Product_Sub_Group Business  \
# 0  JAN-2019  Order Entry-Domestic  KPLO                ML       LB
# 1  JAN-2019  Order Entry-Domestic  KPLO                ML       LB
# 2  JAN-2019    Order Entry-Export  KPLO                FX       FL
# 3  JAN-2019          RMA-Domestic  KPLO                OT       OT
# 4  JAN-2019  Order Entry-Domestic  KPLO                OT       OT
# 5  JAN-2019          RMA-Domestic  KPLO                OT       OT
#
#   Product_Group Print_Technique D_ND Product_Sub_Group__D_ND_ BU_Except_IBD  \
# 0            ML           Flexo   ND                    ML ND           LBD
# 1            ML           Flexo   ND                    ML ND           LBD
# 2     Laminates         Gravure   ND                    FX ND           FBD
# 3        Others             NaN   ND                    OT ND        Others
# 4        Others             NaN   ND                    OT ND        Others
# ...

# %%
df.fillna("")
# Out:
#      Period           Transaction Plant Product_Sub_Group Business  \
# 0  JAN-2019  Order Entry-Domestic  KPLO                ML       LB
# 1  JAN-2019  Order Entry-Domestic  KPLO                ML       LB
# 2  JAN-2019    Order Entry-Export  KPLO                FX       FL
# 3  JAN-2019          RMA-Domestic  KPLO                OT       OT
# 4  JAN-2019  Order Entry-Domestic  KPLO                OT       OT
# 5  JAN-2019          RMA-Domestic  KPLO                OT       OT
#
#   Product_Group Print_Technique D_ND Product_Sub_Group__D_ND_ BU_Except_IBD  \
# 0            ML           Flexo   ND                    ML ND           LBD
# 1            ML           Flexo   ND                    ML ND           LBD
# 2     Laminates         Gravure   ND                    FX ND           FBD
# 3        Others                   ND                    OT ND        Others
# 4        Others                   ND                    OT ND        Others
# ...
